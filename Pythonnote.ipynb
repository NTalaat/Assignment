# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **name : Nora Alshamy**
#
# Student

# %% [markdown]
# *Iam very interested in data science because data is everywhere, from the start of the day till the end. data is being generated non-stop*

# %% [markdown]
# ### in the below code we are doing simple mathematic addition operation ( 1 + 1 = 2)

# %%
1+1
# Out:
# 2

# %% [markdown]
# ![alt text](https://www.idlememe.com/wp-content/uploads/2022/01/good-job-meme-idlememe-3.jpg "Good Job")

# %% [markdown]
# ---

# %% [markdown]
# list of things i need to do :-
# 1. study linear algebra
# 2. study stats.
# 3. study data science
